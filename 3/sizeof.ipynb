# %%
import sys

print(sys.getsizeof(10))
print(sys.getsizeof(3.14))
print(sys.getsizeof("A"))
print(sys.getsizeof([1,2,3]))
# Out:
# 28
# 24
# 50
# 80

# %%
import numpy as np

a = np.array([5, 2, 8, 1, 3])

a.sort()

print(a)
# Out:
# [1 2 3 5 8]

# %%
import os

t = os.times()
print(t)
# Out:
# posix.times_result(user=1.12, system=0.17, children_user=0.0, children_system=0.0, elapsed=17183474.34)

# %%
import os
cores = os.cpu_count()
print(f"코어수 : {cores}")
# Out:
# 코어수 : 6

# %%
import numpy as np

a = np.array([1, 2, 3])

b = a.repeat(2)

print(b)
# Out:
# [1 1 2 2 3 3]

# %%
import numpy as np

a = np.array([1, 2, 3, 4])

a.fill(0)

print(a)
# Out:
# [0 0 0 0]

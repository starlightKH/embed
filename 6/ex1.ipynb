# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('cow.jpg',cv2.IMREAD_COLOR)

plt.imshow(img)
plt.axis('off')
plt.show()

print("이미지 배열\n" , img)
# Out:
# 이미지 배열
#  [[[ 32  75  60]
#   [ 32  75  60]
#   [ 32  75  60]
#   ...
#   [ 21  30  20]
#   [ 21  30  20]
#   [ 21  30  20]]
#
#  [[ 32  75  60]
#   [ 32  75  60]
#   [ 31  74  59]
#   ...
#   [ 21  30  20]
#   [ 21  30  20]
#   [ 21  30  20]]
#
#  [[ 32  75  60]
#   [ 31  74  59]
#   [ 31  74  59]
#   ...
#   [ 21  30  20]
#   [ 21  30  20]
#   [ 21  30  20]]
#
#  ...
#
#  [[ 71  93  91]
#   [ 68  90  88]
#   [ 64  86  84]
#   ...
#   [ 92 109 100]
#   [ 89 106  97]
#   [ 86 103  94]]
#
#  [[ 69  91  89]
#   [ 66  88  86]
#   [ 64  86  84]
#   ...
#   [ 90 107  98]
#   [ 88 105  96]
#   [ 85 102  93]]
#
#  [[ 68  90  88]
#   [ 65  87  85]
#   [ 64  86  84]
#   ...
#   [ 89 106  97]
#   [ 87 104  95]
#   [ 85 102  93]]]
